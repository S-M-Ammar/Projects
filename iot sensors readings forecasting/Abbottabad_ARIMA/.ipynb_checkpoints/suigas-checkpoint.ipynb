# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,10)

# %%
df = pd.read_excel("../data/Abbottabad/gas.xlsx")
df = df[['Sensor Value']]
df
# Out:
#       Sensor Value
# 0               53
# 1               54
# 2               53
# 3               53
# 4               53
# ...            ...
# 1157            93
# 1158            96
# 1159            93
# 1160            93
# 1161            92
#
# [1162 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1162 entries, 0 to 1161
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sensor Value  1162 non-null   int64
# dtypes: int64(1)
# memory usage: 9.2 KB

# %%
Days = pd.date_range(start="2017-09-07",end="2020-06-25")
Days
# Out:
# DatetimeIndex(['2017-09-07', '2017-09-08', '2017-09-09', '2017-09-10',
#                '2017-09-11', '2017-09-12', '2017-09-13', '2017-09-14',
#                '2017-09-15', '2017-09-16',
#                ...
#                '2020-06-16', '2020-06-17', '2020-06-18', '2020-06-19',
#                '2020-06-20', '2020-06-21', '2020-06-22', '2020-06-23',
#                '2020-06-24', '2020-06-25'],
#               dtype='datetime64[ns]', length=1023, freq='D')

# %%
dataframe = pd.DataFrame()
dataframe['ds'] = Days
dataframe['ds'] = dataframe['ds'].dt.date
dataframe['y'] = df[['Sensor Value']]
dataframe
# Out:
#               ds    y
# 0     2017-09-07   53
# 1     2017-09-08   54
# 2     2017-09-09   53
# 3     2017-09-10   53
# 4     2017-09-11   53
# ...          ...  ...
# 1018  2020-06-21  114
# 1019  2020-06-22  114
# 1020  2020-06-23  114
# 1021  2020-06-24  113
# 1022  2020-06-25  113
#
# [1023 rows x 2 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1023 entries, 0 to 1022
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      1023 non-null   object
#  1   y       1023 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 16.1+ KB

# %%
dataframe.plot()

# %%
from statsmodels.tsa.stattools import adfuller
def addfuller_test(data):
    result = adfuller(data)
    labels = ['ADF Test Statistic','p-value','# Lags Used','# Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value))
    if(result[1]<= 0.05):
        print("Data is stationary")
    else:
        print("Data is non stationary")

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(dataframe['y'],lags=100)

# %%
# q = 25

# %%
plot_pacf (dataframe['y'])

# %%
# p = 10

# %%
from statsmodels.tsa.arima_model import ARIMA
X = dataframe['y'].values
size = int(len(X) * 0.70)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]

model = ARIMA(history,order=(15,0,10))
try:
    model_fit = model.fit()
except:
    model_fit = model.fit()
# Out:
# C:\Users\S.M.Ammar\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\S.M.Ammar\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\base\model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  716
# Model:                   ARMA(15, 10)   Log Likelihood               -2412.127
# Method:                       css-mle   S.D. of innovations              7.015
# Date:                Sat, 22 May 2021   AIC                           4878.254
# Time:                        17:24:56   BIC                           5001.744
# Sample:                             0   HQIC                          4925.940
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         57.1360      2.362     24.190      0.000      52.507      61.765
# ar.L1.y        0.9886      0.313      3.155      0.002       0.374       1.603
# ar.L2.y       -0.3745      0.263     -1.427      0.154      -0.889       0.140
# ar.L3.y        0.1898      0.181      1.048      0.294      -0.165       0.545
# ar.L4.y        0.5437      0.155      3.517      0.000       0.241       0.847
# ar.L5.y        0.1688      0.200      0.846      0.398      -0.222       0.560
# ar.L6.y       -0.2788      0.171     -1.630      0.103      -0.614       0.056
# ar.L7.y       -0.2858      0.142     -2.013      0.044      -0.564      -0.008
# ar.L8.y        0.2899      0.157      1.842      0.065      -0.019       0.598
# ar.L9.y       -0.9204      0.156     -5.897      0.000      -1.226      -0.614
# ar.L10.y       0.4297      0.319      1.345      0.179      -0.196       1.056
# ar.L11.y       0.0550      0.143      0.386      0.700      -0.224       0.334
# ar.L12.y       0.0922      0.058      1.584      0.113      -0.022       0.206
# ar.L13.y      -0.0460      0.064     -0.723      0.470      -0.171       0.079
# ar.L14.y       0.2753      0.055      5.051      0.000       0.168       0.382
# ar.L15.y      -0.1713      0.075     -2.273      0.023      -0.319      -0.024
# ma.L1.y       -0.3428      0.315     -1.088      0.277      -0.961       0.275
# ma.L2.y        0.1546      0.110      1.409      0.159      -0.061       0.370
# ma.L3.y        0.0483      0.134      0.360      0.719      -0.215       0.311
# ma.L4.y       -0.5952      0.096     -6.220      0.000      -0.783      -0.408
# ma.L5.y       -0.4028      0.180     -2.239      0.025      -0.755      -0.050
# ma.L6.y       -0.0873      0.187     -0.468      0.640      -0.453       0.279
# ma.L7.y        0.1987      0.104      1.907      0.057      -0.006       0.403
# ma.L8.y       -0.2641      0.101     -2.612      0.009      -0.462      -0.066
# ma.L9.y        0.7019      0.123      5.691      0.000       0.460       0.944
# ma.L10.y      -0.0047      0.238     -0.020      0.984      -0.471       0.461
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.0001           -0.0000j            1.0001           -0.5000
# AR.2            -0.7468           -0.7675j            1.0709           -0.3728
# AR.3            -0.7468           +0.7675j            1.0709            0.3728
# AR.4            -1.0518           -0.6818j            1.2534           -0.4085
# AR.5            -1.0518           +0.6818j            1.2534            0.4085
# AR.6            -0.0343           -1.0610j            1.0616           -0.2551
# AR.7            -0.0343           +1.0610j            1.0616            0.2551
# AR.8             0.3049           -1.1094j            1.1505           -0.2073
# AR.9             0.3049           +1.1094j            1.1505            0.2073
# AR.10            0.4637           -0.9655j            1.0711           -0.1787
# AR.11            0.4637           +0.9655j            1.0711            0.1787
# AR.12            1.0204           -0.2392j            1.0481           -0.0366
# AR.13            1.0204           +0.2392j            1.0481            0.0366
# AR.14            1.0436           -0.0000j            1.0436           -0.0000
# AR.15            1.6516           -0.0000j            1.6516           -0.0000
# MA.1            -1.0000           -0.0000j            1.0000           -0.5000
# MA.2            -0.7808           -0.7176j            1.0605           -0.3817
# MA.3            -0.7808           +0.7176j            1.0605            0.3817
# MA.4             0.0304           -1.0466j            1.0470           -0.2454
# MA.5             0.0304           +1.0466j            1.0470            0.2454
# MA.6             1.0239           -0.1753j            1.0388           -0.0270
# MA.7             1.0239           +0.1753j            1.0388            0.0270
# MA.8             0.4141           -0.9497j            1.0361           -0.1846
# MA.9             0.4141           +0.9497j            1.0361            0.1846
# MA.10          150.3752           -0.0000j          150.3752           -0.0000
# ------------------------------------------------------------------------------
# """

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error
preds = model_fit.forecast(steps=len(test))

# %%
preds = preds[0]
preds = preds.tolist()
preds
# Out:
# [51.72823182168137,
#  52.23938995498173,
#  51.789854829106744,
#  51.906168781383386,
#  52.455410194955206,
#  52.70831587273802,
#  52.76737180314125,
#  52.65128360475857,
#  52.61610693576114,
#  52.928069412395935,
#  53.144292558416076,
#  53.21447944833877,
#  53.26014233345411,
#  53.10584949405085,
#  53.325037256476676,
#  53.704198210538074,
#  53.82477166668027,
#  53.86924368520386,
#  53.87949987281146,
#  54.08456910649917,
#  54.43819034916449,
#  54.53268281041493,
#  54.64847927597486,
#  54.793868682808075,
#  54.902227113595046,
#  55.0707044692718,
#  55.20853931517161,
#  55.32375865118043,
#  55.443244891394286,
#  55.43664632070772,
#  55.515843038808484,
#  55.63290100611978,
#  55.686459075922905,
#  55.72075370348279,
#  55.74053149494829,
#  55.760522626161766,
#  55.8241525357891,
#  55.83168019545418,
#  55.88383432513269,
#  55.930870954334964,
#  57.13736917626867,
#  57.131018161589154,
#  57.137536626251006,
#  57.131170954133495,
#  57.137672463978404,
#  57.13129588726324,
#  57.137786767398715,
#  57.131399955185884,
#  57.13787969705276,
#  57.1314885335137,
#  57.13796532502717,
#  57.13156962060313,
#  57.1380414522183,
#  57.13164669694205,
#  57.13811914302514,
#  57.13172498533334,
#  57.138196105337244,
#  57.13180397102133,
#  57.138276041269,
#  57.13188378265599,
#  57.13835431550105,
#  57.13196313888246,
#  57.138431889149565,
#  57.1320383309273,
#  57.13850296650282,
#  57.13210765478011,
#  57.13856862507717,
#  57.13216913143336,
#  57.1386246014424,
#  57.13222210089647,
#  57.13867275069884,
#  57.13226639943312,
#  57.13871237551206,
#  57.13230371226509,
#  57.13874605886585,
#  57.13233489455508,
#  57.138774338549524,
#  57.13236282729783,
#  57.13880037517005,
#  57.132388307049226,
#  57.13882455027101,
#  57.132413261041066,
#  57.138848843349905,
#  57.13243801093495,
#  57.13887297268497,
#  57.1324631947001,
#  57.138897342429786,
#  57.132487915074236,
#  57.138921160559285,
#  57.1325122032295,
#  57.1389440664397,
#  57.13253477325747,
#  57.138965006879154,
#  57.132555544421976,
#  57.13898382787858,
#  57.1325736828394,
#  57.13900002848293,
#  57.13258941218715,
#  57.13901377523198,
#  57.13260261393616,
#  57.139025279133854,
#  57.132613982802305,
#  57.13903503903552,
#  57.132623685948666,
#  57.13904355868074,
#  57.13263256007724,
#  57.139051372891664,
#  57.13264080655345,
#  57.13905882146512,
#  57.13264894402971,
#  57.13906617121327,
#  57.13265695730187,
#  57.139073513318415,
#  57.132664994562276,
#  57.13908074060455,
#  57.132672807691335,
#  57.13908774655249,
#  57.13268035600114,
#  57.139094307343626,
#  57.13268732249745,
#  57.13910028303436,
#  57.1326936679626,
#  57.13910552982272,
#  57.13269923634262,
#  57.1391100375887,
#  57.13270408948524,
#  57.1391138106024,
#  57.13270824633642,
#  57.13911699666299,
#  57.132711883342445,
#  57.13911968987178,
#  57.13271510285295,
#  57.139122078121666,
#  57.13271809068091,
#  57.139124264181135,
#  57.132720927576386,
#  57.139126371444945,
#  57.13272371342861,
#  57.139128424304076,
#  57.13272646143065,
#  57.13913045833297,
#  57.13272917373188,
#  57.13913242062454,
#  57.13273179952435,
#  57.13913429152206,
#  57.132734301168995,
#  57.139135997166704,
#  57.13273662147111,
#  57.13913751467842,
#  57.13273873376782,
#  57.13913880539269,
#  57.132740621331855,
#  57.13913988217241,
#  57.13274229495294,
#  57.13914074944158,
#  57.13274378214742,
#  57.139141455152874]

# %%
mse = mean_squared_error(test,preds)
mse
# Out:
# 422.2686074327304

# %%
import pickle
with open('gas_model_arima.pkl', 'wb') as fid:
    pickle.dump(model_fit, fid)

# %%
forecasting={
    
    'Day-1':preds[0],
    'Day-2':preds[1],
    'Day-3':preds[2],
    'Day-4':preds[3],
    'Day-5':preds[4],
    'Day-6':preds[5],
    'Day-7':preds[6],
    'MSE': mse
}

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db
cred = credentials.Certificate("../config/sensors-forecasting-fc27d-firebase-adminsdk-krgvi-403182645e.json")
firebase_admin.initialize_app(cred,{'databaseURL':'https://sensors-forecasting-fc27d-default-rtdb.firebaseio.com/'})
ref = db.reference("/Models/ARIMA")
upload_ref = ref.child('SuiGas')
upload_ref.update(forecasting)
