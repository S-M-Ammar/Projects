# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,10)

# %%
df = pd.read_excel("gas.xlsx")
df = df[['Sensor Value']]
df
# Out:
#       Sensor Value
# 0               53
# 1               54
# 2               53
# 3               53
# 4               53
# ...            ...
# 1157            93
# 1158            96
# 1159            93
# 1160            93
# 1161            92
#
# [1162 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1162 entries, 0 to 1161
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sensor Value  1162 non-null   int64
# dtypes: int64(1)
# memory usage: 9.2 KB

# %%
Days = pd.date_range(start="2017-09-07",end="2020-06-25")
Days
# Out:
# DatetimeIndex(['2017-09-07', '2017-09-08', '2017-09-09', '2017-09-10',
#                '2017-09-11', '2017-09-12', '2017-09-13', '2017-09-14',
#                '2017-09-15', '2017-09-16',
#                ...
#                '2020-06-16', '2020-06-17', '2020-06-18', '2020-06-19',
#                '2020-06-20', '2020-06-21', '2020-06-22', '2020-06-23',
#                '2020-06-24', '2020-06-25'],
#               dtype='datetime64[ns]', length=1023, freq='D')

# %%
dataframe = pd.DataFrame()
dataframe['ds'] = Days
dataframe['ds'] = dataframe['ds'].dt.date
dataframe['y'] = df[['Sensor Value']]
dataframe
# Out:
#               ds    y
# 0     2017-09-07   53
# 1     2017-09-08   54
# 2     2017-09-09   53
# 3     2017-09-10   53
# 4     2017-09-11   53
# ...          ...  ...
# 1018  2020-06-21  114
# 1019  2020-06-22  114
# 1020  2020-06-23  114
# 1021  2020-06-24  113
# 1022  2020-06-25  113
#
# [1023 rows x 2 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1023 entries, 0 to 1022
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      1023 non-null   object
#  1   y       1023 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 16.1+ KB

# %%
dataframe.plot()

# %%
from statsmodels.tsa.stattools import adfuller
def addfuller_test(data):
    result = adfuller(data)
    labels = ['ADF Test Statistic','p-value','# Lags Used','# Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value))
    if(result[1]<= 0.05):
        print("Data is stationary")
    else:
        print("Data is non stationary")

# %%
addfuller_test(dataframe['y'])
# Out:
# ADF Test Statistic : -8.368471581450605
# p-value : 2.7023964962078527e-13
# # Lags Used : 0
# # Observations Used : 1022
# Data is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(dataframe['y'])

# %%
plot_pacf (dataframe['y'])

# %%
from statsmodels.tsa.arima_model import ARIMA
X = dataframe['y'].values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]

model = ARIMA(history,order=(15,0,2))
try:
    model_fit = model.fit()
except:
    model_fit = model.fit()
# Out:
# C:\Users\S.M.Ammar\AppData\Local\Programs\Python\Python37\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  675
# Model:                    ARMA(15, 2)   Log Likelihood               -2309.042
# Method:                       css-mle   S.D. of innovations              7.394
# Date:                Wed, 16 Dec 2020   AIC                           4656.084
# Time:                        16:40:18   BIC                           4741.863
# Sample:                             0   HQIC                          4689.298
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         57.2810      2.782     20.589      0.000      51.828      62.734
# ar.L1.y        0.4337      0.071      6.106      0.000       0.295       0.573
# ar.L2.y        0.8905      0.050     17.975      0.000       0.793       0.988
# ar.L3.y       -0.3508      0.066     -5.349      0.000      -0.479      -0.222
# ar.L4.y        0.0244      0.056      0.436      0.663      -0.085       0.134
# ar.L5.y        0.0090      0.056      0.161      0.872      -0.101       0.119
# ar.L6.y       -0.0407      0.056     -0.731      0.465      -0.150       0.069
# ar.L7.y       -0.1098      0.055     -1.983      0.047      -0.218      -0.001
# ar.L8.y        0.0396      0.056      0.713      0.476      -0.069       0.149
# ar.L9.y       -0.0125      0.055     -0.226      0.822      -0.121       0.096
# ar.L10.y      -0.0143      0.055     -0.260      0.795      -0.123       0.094
# ar.L11.y       0.0415      0.055      0.752      0.452      -0.067       0.150
# ar.L12.y      -0.0042      0.055     -0.077      0.939      -0.112       0.104
# ar.L13.y      -0.1038      0.054     -1.935      0.053      -0.209       0.001
# ar.L14.y       0.0743      0.042      1.779      0.075      -0.008       0.156
# ar.L15.y       0.0792      0.041      1.951      0.051      -0.000       0.159
# ma.L1.y        0.2179      0.061      3.573      0.000       0.098       0.338
# ma.L2.y       -0.7695      0.059    -12.948      0.000      -0.886      -0.653
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.0242           -0.0000j            1.0242           -0.0000
# AR.2             1.0290           -0.2920j            1.0696           -0.0440
# AR.3             1.0290           +0.2920j            1.0696            0.0440
# AR.4             0.8918           -0.7915j            1.1924           -0.1155
# AR.5             0.8918           +0.7915j            1.1924            0.1155
# AR.6             0.4231           -1.0919j            1.1710           -0.1912
# AR.7             0.4231           +1.0919j            1.1710            0.1912
# AR.8            -0.1226           -1.1924j            1.1987           -0.2663
# AR.9            -0.1226           +1.1924j            1.1987            0.2663
# AR.10           -0.7330           -0.9616j            1.2092           -0.3537
# AR.11           -0.7330           +0.9616j            1.2092            0.3537
# AR.12           -1.0043           -0.0000j            1.0043           -0.5000
# AR.13           -1.1364           -0.5335j            1.2554           -0.4301
# AR.14           -1.1364           +0.5335j            1.2554            0.4301
# AR.15           -1.6617           -0.0000j            1.6617           -0.5000
# MA.1            -1.0071           +0.0000j            1.0071            0.5000
# MA.2             1.2904           +0.0000j            1.2904            0.0000
# ------------------------------------------------------------------------------
# """

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error
preds = model_fit.forecast(steps=len(test))

# %%
preds = preds[0]
preds = preds.tolist()
preds
# Out:
# [53.39617077372838,
#  52.968418424717136,
#  53.00989477445569,
#  53.109377482866066,
#  53.31990613201711,
#  52.951473998584994,
#  52.90354528632954,
#  52.830377698888306,
#  53.10136786562509,
#  53.07873171759581,
#  53.393308821425,
#  53.197810631759886,
#  53.124322924039134,
#  53.16793858246563,
#  53.435282534292305,
#  53.51246607929293,
#  53.70984063484937,
#  53.72937858077391,
#  53.98574147412663,
#  54.05018040658824,
#  54.25718047495231,
#  54.26540467069397,
#  54.43897113226581,
#  54.41437276904766,
#  54.59546565212783,
#  54.58865881070031,
#  54.728081960364534,
#  54.67347255735383,
#  54.79156556288844,
#  54.74246267291137,
#  54.868303993039206,
#  54.813582422037825,
#  54.934962654683034,
#  54.890117923481995,
#  55.02266120108693,
#  54.98927451683118,
#  55.12970923642926,
#  55.099105739860484,
#  55.23976330291342,
#  55.21459896314405,
#  55.35897188303688,
#  55.33481808514131,
#  55.4736535772543,
#  55.44377588141866,
#  55.57670254600269,
#  55.54184819697245,
#  55.666974737191175,
#  55.62541276127323,
#  55.74292892617693,
#  57.291188729926866,
#  57.2645788146917,
#  57.29122389390719,
#  57.26483659185344,
#  57.29125307640078,
#  57.265086635549814,
#  57.29127659374535,
#  57.26532927068063,
#  57.29129474718523,
#  57.26556480728497,
#  57.29130782359956,
#  57.26579354124705,
#  57.29131609618377,
#  57.26601575495654,
#  57.29131982508764,
#  57.266231717928136,
#  57.291319258015804,
#  57.266441687387,
#  57.29131463079759,
#  57.26664590882683,
#  57.29130616793232,
#  57.26684461654568,
#  57.291294083114146,
#  57.267038034162425,
#  57.291278579738204,
#  57.2672263751148,
#  57.29125985138806,
#  57.26740984313809,
#  57.29123808230314,
#  57.2675886327231,
#  57.29121344782469,
#  57.26776292955206,
#  57.29118611481944,
#  57.267932910912094,
#  57.29115624208079,
#  57.268098746086494,
#  57.291123980708505,
#  57.2682605967254,
#  57.291089474468706,
#  57.2684186171976]

# %%
test = test.tolist()
test
# Out:
# [52,
#  52,
#  54,
#  54,
#  52,
#  54,
#  54,
#  52,
#  52,
#  52,
#  51,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  53,
#  51,
#  52,
#  52,
#  52,
#  52,
#  52,
#  51,
#  50,
#  52,
#  52,
#  51,
#  52,
#  51,
#  52,
#  50,
#  51,
#  51,
#  52,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  50,
#  49,
#  51,
#  51,
#  49,
#  51,
#  51,
#  51,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  49,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  49,
#  49,
#  49,
#  49,
#  49,
#  49,
#  49,
#  49,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  49,
#  49,
#  49,
#  49,
#  49,
#  49,
#  49,
#  49,
#  49,
#  48,
#  49,
#  48,
#  49,
#  48,
#  48,
#  54,
#  54,
#  54,
#  53,
#  54,
#  52,
#  53,
#  60,
#  53,
#  54,
#  54,
#  57,
#  55,
#  56,
#  53,
#  55,
#  56,
#  55,
#  54,
#  55,
#  55,
#  55,
#  56,
#  59,
#  55,
#  55,
#  57,
#  55,
#  62,
#  58,
#  56,
#  57,
#  56,
#  55,
#  56,
#  55,
#  57,
#  56,
#  55,
#  55,
#  56,
#  54,
#  55,
#  55,
#  54,
#  55,
#  55,
#  54,
#  55,
#  55,
#  54,
#  55,
#  55,
#  55,
#  54,
#  55,
#  55,
#  55,
#  54,
#  56,
#  55,
#  54,
#  54,
#  55,
#  54,
#  52,
#  52,
#  52,
#  53,
#  54,
#  55,
#  52,
#  53,
#  54,
#  52,
#  51,
#  51,
#  52,
#  52,
#  57,
#  59,
#  57,
#  54,
#  54,
#  55,
#  55,
#  54,
#  56,
#  56,
#  56,
#  57,
#  55,
#  54,
#  61,
#  57,
#  58,
#  47,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  53,
#  51,
#  51,
#  50,
#  50,
#  49,
#  48,
#  50,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  48,
#  47,
#  47,
#  46,
#  46,
#  47,
#  46,
#  46,
#  47,
#  48,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  47,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  28,
#  0,
#  32,
#  42,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  123,
#  121,
#  128,
#  121,
#  121,
#  118,
#  116,
#  117,
#  117,
#  116,
#  114,
#  117,
#  115,
#  115,
#  115,
#  115,
#  114,
#  115,
#  114,
#  114,
#  114,
#  114,
#  113,
#  113]

# %%
mean_squared_error(test,preds)
# Out:
# 375.9771937305626
